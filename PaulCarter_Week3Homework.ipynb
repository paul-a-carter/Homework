# %% [markdown]
# #### Homework 3 Answers
#
# - An **algorithm** is a series of steps to solve a problem at hand.
# - Variable names may not start with *numbers* or *special characters* other than underscores (e.g., an *exclamation point*).
# - **Semantic errors** are when code is grammatically correct but doesn't make any sense; it does not produce the expected results.
# - The **number one rule** of coding and debugging is: Complexity is the enemy of efficiency!
# - 5 Python reserved words: *TRUE*, *FALSE*, *and*, *or*, and *not*.

# %%
# Question 6

# My name is Paul Carter.
# My favorite food is shrimp and grits.
# My dream job would be running a scotch distillery.

# Question 7

var1 = "neato mosquito"
var2 = 92
var3 = 2.4
var4 = False
var5 = ["Mario","Luigi",64]

print(len(var1))

print(var1[3])

# Question 8

savvy = "Learning Data Analytics and Python is Awesome!"

print(savvy[5:24])

savvy.replace("Awesome","great")

print(savvy)

# Question 9

name,age,length = "Paul",24,6.08

miniBio = (f"Hi my name is {name}, I am {length} feet tall and {age} years old today.")

print(miniBio)

age = float(24)
print(age)

# Question 10

list1 = ["Chiefs",{"Head Coach":"Andy Reid"},True,87,142.2]

list1[2] = False

list1.append("Travis Kelce")
list1.append(106.5)
list1.append(["Offense","Defense","Special Teams"])
list1.append(15)

print(len(list1))

list2 = list1[1:6]

print(list2)

list1.extend(list2)

simList = [15,95,8,87,10]

print(sorted(simList))

list3 = simList.copy()

list4 = list2 + list3

# Question 11

tuple1 = ("Yellow","Red","Blue","Orange","Purple","Green")

tuple2 = tuple1*3

print(tuple2[11])

print(sorted(tuple2))

tuple3 = tuple2[-6:-2]

print(tuple3)
a = tuple3[0]
print(a)
b = tuple3[1]
print(b)
c = tuple3[2]
print(c)
d = tuple3[3]
print(d)

tuple4 = (50,)
print(tuple4)

tuple5 = tuple2 + tuple3
print(tuple5)

# Question 12

set1 = {"Broccoli","Edamame","Zucchini"}

set1.update(["Banana","Apple","Peach"])
print(set1)

set1.add("Kia")

set2 = {23,"groovy",3.14159}

set3 = set1.union(set2)

set2.pop()
print(set2)

set1.clear()
print(set1)

set3.discard("Zucchini")
set3.remove("Peach")

print(set3)

# Question 13

dict1 = {
    "name":"augustine",
    "age":24,
    "height":6.08,
    "favorite teams":["chiefs","cardinals","blues"],
    "employed":True
}

print(dict1.get("height"))

dict1.update({"name":"paul carter"})

dict1.update({"favorite color":"yellow"})

dict1.update({"schools":("FBA","UofSC","Savvy Coders")})

print(dict1.keys())

print(dict1.values())

dict2 = dict1.copy()

dict2.popitem()
print(dict2)

dict2.clear()
print(dict2)
# Out:
# 14
# t
# ing Data Analytics
# Learning Data Analytics and Python is Awesome!
# Hi my name is Paul, I am 6.08 feet tall and 24 years old today.
# 24.0
# 9
# [{'Head Coach': 'Andy Reid'}, False, 87, 142.2, 'Travis Kelce']
# [8, 10, 15, 87, 95]
# Green
# ['Blue', 'Blue', 'Blue', 'Green', 'Green', 'Green', 'Orange', 'Orange', 'Orange', 'Purple', 'Purple', 'Purple', 'Red', 'Red', 'Red', 'Yellow', 'Yellow', 'Yellow']
# ('Yellow', 'Red', 'Blue', 'Orange')
# Yellow
# Red
# Blue
# Orange
# (50,)
# ('Yellow', 'Red', 'Blue', 'Orange', 'Purple', 'Green', 'Yellow', 'Red', 'Blue', 'Orange', 'Purple', 'Green', 'Yellow', 'Red', 'Blue', 'Orange', 'Purple', 'Green', 'Yellow', 'Red', 'Blue', 'Orange')
# {'Peach', 'Apple', 'Banana', 'Zucchini', 'Broccoli', 'Edamame'}
# {3.14159, 23}
# set()
# {'groovy', 3.14159, 'Kia', 'Apple', 'Banana', 23, 'Broccoli', 'Edamame'}
# 6.08
# dict_keys(['name', 'age', 'height', 'favorite teams', 'employed', 'favorite color', 'schools'])
# ...
